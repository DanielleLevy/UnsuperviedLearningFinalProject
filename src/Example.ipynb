# %% [markdown]
# ## This serves as a virtual machine to test the running commands in the repository

# %% [markdown]
# 0. We mount the Drive where we have the files. Simulating a user clonning the repository

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Pablo
% cd /content/drive/My Drive/Datasets/Repository/src
# Out:
# /content/drive/My Drive/Datasets/Repository/src

# %% [markdown]
# 0.1. Install the BioPython Dependencies

# %%
# !pip install biopython
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: /Applications/Xcode.app/Contents/Developer/usr/bin/python3 -m pip install --upgrade pip

# %% [markdown]
# 1. Build the dataset

# %%
# !python3 build_dp.py --data_path='../data/Fish/Test Files/Cypriniformes'
# Out:
# Traceback (most recent call last):
#   File "/Users/dani/PycharmProjects/UnsuperviedLearningFinalProject/DeLUCS/src/build_dp.py", line 15, in <module>
#     from Bio import SeqIO
# ModuleNotFoundError: No module named 'Bio'

# %% [markdown]
# 2. Compute the mimic sequences

# %%
# !python get_pairs.py --data_path='../data/Fish/Test Files/Cypriniformes/train.p' --k=6 --n_mimics=8 --modify='mutation' --output='../data/Fish/Test Files/Cypriniformes/testing_data.p'
# Out:
# ............computing learning pairs................
# ......saving mutated pairs.....

# %% [markdown]
# 3. Run the desired commands:
#   * Single Run.
#   * Single Evaluation.
#   * Train DeLUcs.
#   * Evaluate DeLUCS.

# %%
# !python3 EvaluateDeLUCS.py --data_dir='../data/Fish/Test Files/Cypriniformes' --out_dir='../data/Fish/Test Files/Cypriniformes'
# Out:
# The size of the training array is: (9810, 2, 4096)
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# [0.6, 0.7247706422018348, 0.6018348623853211, 0.581651376146789, 0.6311926605504588, 0.691743119266055, 0.7339449541284404, 0.5596330275229358, 0.6788990825688074, 0.7926605504587156]
# [[70  0  0  0  0  0  0]
#  [ 0 55  0  0  0 20  0]
#  [ 0 21 57  0  0  2  0]
#  [11  0  0 55 14  0  0]
#  [ 0  0  0  5 73  2  0]
#  [ 0 31  4  0  0 45  0]
#  [ 3  0  0  1  4  1 71]]
# accuracy:  0.7816513761467891
# <Figure size 800x600 with 2 Axes>
